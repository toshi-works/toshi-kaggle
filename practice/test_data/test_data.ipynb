# %%
import pandas as pd
df = pd.read_csv('sales_tool_log.csv')
df.head()
# Out:
#                  日時     担当者      アクション         取引先企業  滞在時間(分)
# 0  2026-04-01 09:07   田中 健太      見積書作成       C流通システム       16
# 1  2026-04-01 09:56   渡辺 直樹  案件ステータス更新       C流通システム       23
# 2  2026-04-01 11:03   田中 健太     顧客情報閲覧       株式会社A商事       26
# 3  2026-04-01 11:04   田中 健太  案件ステータス更新          Dフーズ       42
# 4  2026-04-02 12:59  高橋 くるみ  案件ステータス更新  Eマニュファクチャリング       26

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...
